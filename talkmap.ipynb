# %% [markdown]
# # Leaflet cluster map of talk locations
#
# Run this from the _talks/ directory, which contains .md files of all your talks. This scrapes the location YAML field from each .md file, geolocates it with geopy/Nominatim, and uses the getorg library to output data, HTML, and Javascript for a standalone cluster map.

# %%
# !pip install getorg --upgrade
import glob
import getorg
from geopy import Nominatim
# Out:
# WARNING: Skipping /Users/lasith/anaconda3/envs/ruractive/lib/python3.12/site-packages/pillow-10.4.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/lasith/anaconda3/envs/ruractive/lib/python3.12/site-packages/pillow-10.4.0.dist-info due to invalid metadata entry 'name'
# Collecting getorg
#   Downloading getorg-0.3.1-py2.py3-none-any.whl.metadata (326 bytes)
# Requirement already satisfied: geopy in /Users/lasith/anaconda3/envs/ruractive/lib/python3.12/site-packages (from getorg) (2.4.1)
# Collecting pygithub (from getorg)
#   Downloading PyGithub-2.6.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting retrying (from getorg)
#   Downloading retrying-1.4.1-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: geographiclib<3,>=1.52 in /Users/lasith/anaconda3/envs/ruractive/lib/python3.12/site-packages (from geopy->getorg) (1.52)
# Collecting pynacl>=1.4.0 (from pygithub->getorg)
#   Downloading PyNaCl-1.5.0-cp36-abi3-macosx_10_10_universal2.whl.metadata (8.7 kB)
# Requirement already satisfied: requests>=2.14.0 in /Users/lasith/anaconda3/envs/ruractive/lib/python3.12/site-packages (from pygithub->getorg) (2.31.0)
# Requirement already satisfied: pyjwt>=2.4.0 in /Users/lasith/anaconda3/envs/ruractive/lib/python3.12/site-packages (from pyjwt[crypto]>=2.4.0->pygithub->getorg) (2.8.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/lasith/anaconda3/envs/ruractive/lib/python3.12/site-packages (from pygithub->getorg) (4.12.2)
# Requirement already satisfied: urllib3>=1.26.0 in /Users/lasith/anaconda3/envs/ruractive/lib/python3.12/site-packages (from pygithub->getorg) (2.2.2)
# Requirement already satisfied: Deprecated in /Users/lasith/anaconda3/envs/ruractive/lib/python3.12/site-packages (from pygithub->getorg) (1.2.14)
# Collecting cryptography>=3.4.0 (from pyjwt[crypto]>=2.4.0->pygithub->getorg)
#   Downloading cryptography-45.0.5-cp311-abi3-macosx_10_9_universal2.whl.metadata (5.7 kB)
# Requirement already satisfied: cffi>=1.4.1 in /Users/lasith/anaconda3/envs/ruractive/lib/python3.12/site-packages (from pynacl>=1.4.0->pygithub->getorg) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/lasith/anaconda3/envs/ruractive/lib/python3.12/site-packages (from requests>=2.14.0->pygithub->getorg) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/lasith/anaconda3/envs/ruractive/lib/python3.12/site-packages (from requests>=2.14.0->pygithub->getorg) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/lasith/anaconda3/envs/ruractive/lib/python3.12/site-packages (from requests>=2.14.0->pygithub->getorg) (2024.7.4)
# Requirement already satisfied: wrapt<2,>=1.10 in /Users/lasith/anaconda3/envs/ruractive/lib/python3.12/site-packages (from Deprecated->pygithub->getorg) (1.16.0)
# Requirement already satisfied: pycparser in /Users/lasith/anaconda3/envs/ruractive/lib/python3.12/site-packages (from cffi>=1.4.1->pynacl>=1.4.0->pygithub->getorg) (2.22)
# Downloading getorg-0.3.1-py2.py3-none-any.whl (39 kB)
# Downloading PyGithub-2.6.1-py3-none-any.whl (410 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.5/410.5 kB 6.3 MB/s eta 0:00:006.8 MB/s eta 0:00:01
# Downloading retrying-1.4.1-py3-none-any.whl (12 kB)
# Downloading PyNaCl-1.5.0-cp36-abi3-macosx_10_10_universal2.whl (349 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 349.9/349.9 kB 32.5 MB/s eta 0:00:00
# Downloading cryptography-45.0.5-cp311-abi3-macosx_10_9_universal2.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 48.1 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# WARNING: Skipping /Users/lasith/anaconda3/envs/ruractive/lib/python3.12/site-packages/pillow-10.4.0.dist-info due to invalid metadata entry 'name'
# Installing collected packages: retrying, pynacl, cryptography, pygithub, getorg
# WARNING: Skipping /Users/lasith/anaconda3/envs/ruractive/lib/python3.12/site-packages/pillow-10.4.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/lasith/anaconda3/envs/ruractive/lib/python3.12/site-packages/pillow-10.4.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/lasith/anaconda3/envs/ruractive/lib/python3.12/site-packages/pillow-10.4.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/lasith/anaconda3/envs/ruractive/lib/python3.12/site-packages/pillow-10.4.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/lasith/anaconda3/envs/ruractive/lib/python3.12/site-packages/pillow-10.4.0.dist-info due to invalid metadata entry 'name'
# Successfully installed cryptography-45.0.5 getorg-0.3.1 pygithub-2.6.1 pynacl-1.5.0 retrying-1.4.1
# WARNING: Skipping /Users/lasith/anaconda3/envs/ruractive/lib/python3.12/site-packages/pillow-10.4.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/lasith/anaconda3/envs/ruractive/lib/python3.12/site-packages/pillow-10.4.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/lasith/anaconda3/envs/ruractive/lib/python3.12/site-packages/pillow-10.4.0.dist-info due to invalid metadata entry 'name'
# Iywidgets and ipyleaflet support disabled. You must be in a Jupyter notebook to use this feature.
# Error raised:
# No module named 'ipyleaflet'
# Check that you have enabled ipyleaflet in Jupyter with:
#     jupyter nbextension enable --py ipyleaflet

# %%
g = glob.glob("*.md")

# %%
geocoder = Nominatim()
location_dict = {}
location = ""
permalink = ""
title = ""
# Out:
# ---------------------------------------------------------------------------
# ConfigurationError                        Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 geocoder = Nominatim()
#       2 location_dict = {}
#       3 location = ""
#
# File ~/anaconda3/envs/ruractive/lib/python3.12/site-packages/geopy/geocoders/nominatim.py:105, in Nominatim.__init__(self, timeout, proxies, domain, scheme, user_agent, ssl_context, adapter_factory)
#     101 self.domain = domain.strip('/')
#     103 if (self.domain == _DEFAULT_NOMINATIM_DOMAIN
#     104         and self.headers['User-Agent'] in _REJECTED_USER_AGENTS):
# --> 105     raise ConfigurationError(
#     106         'Using Nominatim with default or sample `user_agent` "%s" is '
#     107         'strongly discouraged, as it violates Nominatim\'s ToS '
#     108         'https://operations.osmfoundation.org/policies/nominatim/ '
#     109         'and may possibly cause 403 and 429 HTTP errors. '
#     110         'Please specify a custom `user_agent` with '
#     111         '`Nominatim(user_agent="my-application")` or by '
#     112         'overriding the default `user_agent`: '
#     113         '`geopy.geocoders.options.default_user_agent = "my-application"`.'
#     114         % self.headers['User-Agent']
#     115     )
#     117 self.api = "%s://%s%s" % (self.scheme, self.domain, self.geocode_path)
#     118 self.reverse_api = "%s://%s%s" % (self.scheme, self.domain, self.reverse_path)
#
# ConfigurationError: Using Nominatim with default or sample `user_agent` "geopy/2.4.1" is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`.

# %%
for file in g:
    with open(file, 'r') as f:
        lines = f.read()
        if lines.find('location: "') > 1:
            loc_start = lines.find('location: "') + 11
            lines_trim = lines[loc_start:]
            loc_end = lines_trim.find('"')
            location = lines_trim[:loc_end]
                            
           
        location_dict[location] = geocoder.geocode(location)
        print(location, "\n", location_dict[location])
# Out:
# Berkeley CA, USA
#  Berkeley, Alameda County, California, United States of America
# Los Angeles, CA
#  LA, Los Angeles County, California, United States of America
# London, UK
#  London, Greater London, England, UK
# San Francisco, California
#  SF, California, United States of America

# %%
m = getorg.orgmap.create_map_obj()
getorg.orgmap.output_html_cluster_map(location_dict, folder_name="../talkmap", hashed_usernames=False)
# Out:
# 'Written map to ../talkmap/'
